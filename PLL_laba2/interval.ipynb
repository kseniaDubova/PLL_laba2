# %%
data_16 = [
    [0.033000, 0.025000,  0.024000,  0.017000,  0.024000,  0.016000,  0.017000,  0.019000,  0.020000,  0.021000],
    [0.433000,  0.213000,  0.206000,  0.209000,  0.208000,  0.239000,  0.217000,  0.210000,  0.211000,  0.211000],
    [1.231000,  0.970000,  0.964000,  0.988000,  0.986000,  1.008000,  0.988000,  1.007000,  0.983000,  0.965000],
    [4.115000,  3.911000,  3.931000,  3.932000,  3.911000,  3.915000,  3.927000,  3.911000,  3.947000,  3.902000],  
    [7.981000,  7.815000,  7.894000,  8.294000,  7.875000,  7.816000,  7.800000,  7.783000,  7.764000,  7.768000],  
    [17.720000,  14.124000,  10.095000,  10.322000,  10.388000,  10.313000,  10.426000,  10.332000,  10.729000,  10.290000],  
    [17.720000,  14.124000,  10.095000,  10.322000,  10.388000,  10.313000,  10.426000,  10.332000,  10.729000,  10.290000],  
    [30.328000,  30.875000,  30.354000,  30.444000,  28.340000,  28.385000,  28.475000,  28.478000,  28.631000,  28.512000],
    [38.659000,  39.337000,  40.469000,  41.388000,  41.277000,  41.334000,  41.349000,  41.364000,  41.267000,  41.359000]  
]

# %%
import numpy as np
import scipy.stats

def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return  m-h, m+h

# %%
size = [100, 300, 500, 800, 1000, 1300, 1500, 1800, 2000]

for i,j in zip(data_16, size):
    print(f"Размер: {j}, Доверительный интервал: {mean_confidence_interval(i)}")
# Out:
# Размер: 100, Доверительный интервал: (0.017933723158841286, 0.025266276841158716)
# Размер: 300, Доверительный интервал: (0.18565562731821433, 0.2857443726817856)
# Размер: 500, Доверительный интервал: (0.9521412498441686, 1.0658587501558312)
# Размер: 800, Доверительный интервал: (3.895221802196609, 3.985178197803391)
# Размер: 1000, Доверительный интервал: (7.764161509999557, 7.993838490000444)
# Размер: 1300, Доверительный интервал: (9.687091331905886, 13.260708668094114)
# Размер: 1500, Доверительный интервал: (9.687091331905886, 13.260708668094114)
# Размер: 1800, Доверительный интервал: (28.522980017867006, 30.041419982132993)
# Размер: 2000, Доверительный интервал: (40.07139345349684, 41.489206546503155)
