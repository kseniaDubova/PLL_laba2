# %% [markdown]
# Отчет по лабораторной работе №2
#
#
# Выполнила: Дубова Ксения 6311-100503D
#
# Характеристики:
# Процессор - AMD Ryzen 7 5800HS with Radeon,
# ОП - 16 ГБ (доступно 15,4),
# Система - 64-разрядная, процессор х64,

# %% [markdown]
# ![](img.png)

# %% [markdown]
# Вывод:
# Результаты подсчета времени для перемножения квадратных матриц в файлах result_1.txt (1 ядро), result_16.txt (16 ядер) проверка результата перемножения в python_res.txt
#
# По результам работы был составлены графики (для 1 потока/16 потоков) зависимости затраченного времени на перемножение двух матриц от размера матрицы nxn.
# Так же были подсчитаны доверительные интервалы - файл interval.ipynb
